# %%
from dotenv import load_dotenv, find_dotenv

# 在 Notebook 环境下经常会存在“系统环境变量已经设置过旧 key”，
# 而 load_dotenv 默认不会覆盖它们（override=False）。
# 这里强制用 .env 覆盖，避免一直用到旧/错的 token。
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='f6069a7a-560a-4d92-9ae6-2e000787b6f6'),
#               AIMessage(content='Nice to meet you, Seán! Green is a fantastic color—calming and vibrant. Is there something you’d like to talk about or anything I can help with today? We could chat about hobbies, plants, sustainability, or anything else you’re into.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 319, 'prompt_tokens': 18, 'total_tokens': 337, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CqyBjhfqd9mWNJvdGgeJyHsPgnzzi', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b59ef-e465-71c1-930e-7f1363257299-0', usage_metadata={'input_tokens': 18, 'output_tokens': 319, 'total_tokens': 337, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='a9e7f929-6b0a-4499-a971-a387c8e35451'),
#               AIMessage(content='I don’t know your favourite color yet. If you’d like, we can figure it out with a quick little quiz, or you can tell me some colors you already like and I’ll guess from there.\n\nWant to do a quick 3-question mini-quiz? Answer with A, B, or C for each:\n1) Do you prefer warm colors (red, orange, yellow) or cool colors (blue, green, purple)? A warm, B cool, C both\n2) Do you like bright saturated colors or soft pastels? A bright, B pastel, C both\n3) Do you want colors that feel energetic and bold or calm and soothing? A energetic/bold, B calming/soothing, C both\n\nTell me your choices and I’ll give you a best guess about your likely favourite color. If you’d rather, just tell me a few colors you like and I’ll pick a top pick for you.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2185, 'prompt_tokens': 11, 'total_tokens': 2196, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1984, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CqyDsfnc9S7PB4DROTqRBUkkHCWp1', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b59f1-ea48-7f13-904a-3172f849a3c4-0', usage_metadata={'input_tokens': 11, 'output_tokens': 2185, 'total_tokens': 2196, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1984}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='3b10f7a3-b059-498e-8649-1ddcf92eb1d1'),
#               AIMessage(content='Hi Seán! Nice to meet you. Green is a great color—calming and connected to nature. What would you like to do or chat about today? If you’d like, I can use your name in our conversation and tailor my responses to your interests.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 512, 'prompt_tokens': 18, 'total_tokens': 530, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cqzw1ccMbGmq8SunqGZXnRaRiycaC', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b5a56-5653-7b01-a261-56e77c69f0af-0', usage_metadata={'input_tokens': 18, 'output_tokens': 512, 'total_tokens': 530, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='3b10f7a3-b059-498e-8649-1ddcf92eb1d1'),
#               AIMessage(content='Hi Seán! Nice to meet you. Green is a great color—calming and connected to nature. What would you like to do or chat about today? If you’d like, I can use your name in our conversation and tailor my responses to your interests.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 512, 'prompt_tokens': 18, 'total_tokens': 530, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cqzw1ccMbGmq8SunqGZXnRaRiycaC', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b5a56-5653-7b01-a261-56e77c69f0af-0', usage_metadata={'input_tokens': 18, 'output_tokens': 512, 'total_tokens': 530, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='93b595eb-4c8b-415f-bc6b-7fa8bb13d12f'),
#               AIMessage(content='Your favourite colour is green. Want to chat about green things, or anything else?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 219, 'prompt_tokens': 87, 'total_tokens': 306, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CqzwLwr5q4QLreGurrDw8o7DYSlON', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b5a56-a3b7-7180-8f8c-1a5868ad2ed8-0', usage_metadata={'input_tokens': 87, 'output_tokens': 219, 'total_tokens': 306, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})]}
