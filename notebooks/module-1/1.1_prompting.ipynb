# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one—the Moon isn’t a country or government, so it has no capital.
#
# If you’re playing with words, the “capital” of the word moon is the letter M (i.e., uppercase M).

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setting, the capital of the Moon is Lunaris Prime, also known to locals as Selene City.
#
# - Location and layout: Lunaris Prime sits along the rim of the Shackleton crater in the Moon’s southern polar region. It’s built around a central arcology known as the Crescent Spire, ringed by pressure-domed districts that drift above a sea of regolith. The city feeds on polar ice, solar energy, and advanced 3D‑printing on a grand scale.
# - Government: The Circular Concord, a council drawn from the Moon’s districts, governs Lunaris Prime and coordinates with Earth’s planetary authorities. Policy is guided by a balance of science, industry, and cultural preservation.
# - Architecture and vibe: The skyline is a lattice of polished lunar glass, basalt columns, and transparent cryo-structures. Night and day blur inside the domes thanks to solar mirrors and illuminated skyways; a city of light that never truly sleeps.
# - Notable districts and landmarks:
#   - The Crescent Spire: the tallest arcology and symbol of lunar sovereignty.
#   - The Dawn Quarter: where sunrise domes glow with aurora-like light from solar concentrators.
#   - The Echo Archive: a soundless library carved into glass and basalt, preserving knowledge in micro-etched light.
#   - The Hydro Gardens: indoor biomes growing crops from recycled water ice.
#   - The Night Market: a perpetual bazaar where traders trade in water ice, lunar minerals, and rare holographic art.
# - Culture and life: Residents call themselves “Lunans.” They value resilience, engineering ingenuity, and storytelling that blends Earth heritage with lunar myths. In festivals during eclipses, the city’s light choreography creates a celestial show visible from Earth.
#
# If you’d like, I can tailor Lunaris Prime to a different mood—gritty frontier, aristocratic capital, or a bustling scientific hub. What vibe are you imagining?

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunovia

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaris Prime
# Location: Shackleton Crater rim, lunar south pole
# Vibe: Austere, radiant, resilient
# Economy: Helium-3 mining; water-ice extraction; solar-energy production; microgravity manufacturing; spaceport services and logistics; lunar research and biotech

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaopolis', location='South polar Shackleton Crater rim, shielded by regolith with solar concentrators, connected to a lunar spaceport and orbital depots.', vibe='A gleaming, dome-covered metropolis of glass and frost, neon-lit in the perpetual twilight, blending frontier grit with scholarly sophistication.', economy='Resource-driven and high-tech: helium-3 and water-ice mining, solar power generation, 3D-printed habitat production, and lunar logistics; a hub for science, manufacturing, and space-tourism.')

# %%
response["structured_response"].name
# Out:
# 'Lunaopolis'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaopolis is a city located at South polar Shackleton Crater rim, shielded by regolith with solar concentrators, connected to a lunar spaceport and orbital depots.
