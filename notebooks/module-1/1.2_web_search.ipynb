# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv, find_dotenv

# 在 Notebook 环境下经常会存在“系统环境变量已经设置过旧 key”，
# 而 load_dotenv 默认不会覆盖它们（override=False）。
# 这里强制用 .env 覆盖，避免一直用到旧/错的 token。
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My training data goes up to around June 2024. I don’t have real-time browsing by default, so I may not know about events or developments after that unless you provide sources or enable browsing in your environment. I can help summarize or analyze any up-to-date material you share, or help you craft queries to find current information.

# %%
question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# London Breed. If you’d like, I can point you to a current official source to verify.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.9996018,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured ...",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.9986223,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.99469805,
#    'raw_content': None},
#   {'url': 'https://www.npr.org/2024/11/24/nx-s1-5190796/san-franciscos-incoming-mayor-has-never-held-public-office-thats-part-of-his-appeal',
#    'title': "San Francisco's incoming mayor has never held public ...",
#    'content': 'Daniel Lurie is the first person in nearly a century to be elected mayor without prior experience in City Hall. Lurie defeated Mayor London',
#    'score': 0.99346113,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=Qvl6AMoZCoI',
#    'title': 'San Francisco Mayor-elect Daniel Lurie on transforming the city',
#    'content': "In a CNBC exclusive, San Francisco's new Mayor-elect Daniel Lurie sits down with Kate Rogers to talk about bringing remote workers back,",
#    'score': 0.9921233,
#    'raw_content': None}],
#  'response_time': 1.09,
#  'request_id': 'f724e061-2ba1-46f8-9c2f-14995b7ed8d8'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='be1cca77-8ab2-418e-9648-fa15f9ef035d'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 354, 'prompt_tokens': 133, 'total_tokens': 487, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cqy3SMDu3x4SnpvqI5wj003ojPtCR', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b59e8-0f96-77a2-a238-36ad187b97a1-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'Who is the current mayor of San Francisco 2025'}, 'id': 'call_I34ek4ZoiyWbKrA2CZm0BeL8', 'type': 'tool_call'}], usage_metadata={'input_tokens': 133, 'output_tokens': 354, 'total_tokens': 487, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}),
#  ToolMessage(content='{"query": "Who is the current mayor of San Francisco 2025", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Daniel_Lurie", "title": "Daniel Lurie - Wikipedia", "content": "Daniel Lawrence Lurie (born 4 February 1977) is an American politician and philanthropist who is the 46th and current mayor of San Francisco, serving since 2025", "score": 0.92825955, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Mayor_of_San_Francisco", "title": "Mayor of San Francisco - Wikipedia", "content": "Incumbent Daniel Lurie. since January 8, 2025. Government of San Francisco ; Incumbent Daniel Lurie. since January 8, 2025. Government of San Francisco · His", "score": 0.90593183, "raw_content": null}, {"url": "https://www.sfchronicle.com/sf/article/daniel-lurie-was-sworn-in-as-s-f-mayor-20013863.php", "title": "Daniel Lurie was sworn in as S.F. mayor. Here\'s what he\'ll tackle now", "content": "Mayor-elect Daniel Lurie is sworn in as Mayor in San Francisco on Wednesday, January 8, 2025.", "score": 0.88822687, "raw_content": null}, {"url": "https://www.latimes.com/california/story/2025-01-08/daniel-lurie-inaugurated-as-san-francisco-mayor", "title": "Daniel Lurie inaugurated as San Francisco\'s new mayor", "content": "Levi Strauss heir and nonprofit executive Daniel Lurie was sworn in Wednesday as the 46th mayor of San Francisco. He vowed a \\"new era of", "score": 0.8865877, "raw_content": null}, {"url": "https://www.sf.gov/departments--office-mayor", "title": "Office of the Mayor - SF.gov", "content": "Daniel Lurie is the 46th Mayor of the City and County of San Francisco ... December 17, 2025 · Mayor Lurie Announces 90 New Beds, Including Locked Mental", "score": 0.8684817, "raw_content": null}], "response_time": 0.66, "request_id": "1385afa7-b077-4726-9775-09c6f13ddaef"}', name='web_search', id='16bb3135-5e81-4f5f-91a9-01252e8ca36a', tool_call_id='call_I34ek4ZoiyWbKrA2CZm0BeL8'),
#  AIMessage(content='Daniel Lurie is the current mayor of San Francisco. He was sworn in as the city’s 46th mayor on January 8, 2025. \n\nSources: SF Chronicle, Los Angeles Times, Wikipedia (on the current officeholder).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 892, 'prompt_tokens': 716, 'total_tokens': 1608, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cqy3aZJMvPyewimhrRFWaVWvVXENZ', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b59e8-3886-7633-94fe-9ade7c78a1f0-0', usage_metadata={'input_tokens': 716, 'output_tokens': 892, 'total_tokens': 1608, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
