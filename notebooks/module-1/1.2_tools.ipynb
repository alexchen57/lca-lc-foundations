# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv, find_dotenv

# 在 Notebook 环境下经常会存在“系统环境变量已经设置过旧 key”，
# 而 load_dotenv 默认不会覆盖它们（override=False）。
# 这里强制用 .env 覆盖，避免一直用到旧/错的 token。
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %%
square_root.invoke({"x":467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=[square_root],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately 21.61018278497431.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='e01d4136-82e5-44f2-8e8f-aface687b652'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1304, 'prompt_tokens': 158, 'total_tokens': 1462, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1280, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CqcxRVInzR9btLLIEMeSNzVcNzhkw', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b5512-a75e-7c43-98ab-f77fc2e1e883-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_UajBU8hEzoBOVd5rNncRPi8Y', 'type': 'tool_call'}], usage_metadata={'input_tokens': 158, 'output_tokens': 1304, 'total_tokens': 1462, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1280}}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='5f393471-f500-4e57-98f9-2a0482a3c97c', tool_call_id='call_UajBU8hEzoBOVd5rNncRPi8Y'),
#  AIMessage(content='The square root of 467 is approximately 21.61018278497431.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 283, 'prompt_tokens': 193, 'total_tokens': 476, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cqcxa9nzIIHonKq2vqu7uap73cOG1', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b5512-ca3c-7ed2-9bec-71a7b5784c3f-0', usage_metadata={'input_tokens': 193, 'output_tokens': 283, 'total_tokens': 476, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_UajBU8hEzoBOVd5rNncRPi8Y', 'type': 'tool_call'}]
