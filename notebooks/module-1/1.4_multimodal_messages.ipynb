# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv, find_dotenv

# 在 Notebook 环境下经常会存在“系统环境变量已经设置过旧 key”，
# 而 load_dotenv 默认不会覆盖它们（override=False）。
# 这里强制用 .env 覆盖，避免一直用到旧/错的 token。
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this science-fiction setting, the Moon’s capital is Selene Prime, also known as Crescent City.
#
# - Location: perched on the rim of Shackleton Crater at the lunar south pole, ringed by solar towers that keep the city lit almost constantly.
# - Architecture: a glittering mosaic of glass-domed districts and lattice-fiber towers rising from a cradle of subterranean bays and farms.
# - Government: seat of the Lunar Directorate, led by the First Luminary, with a council that represents mining, science, and settlement interests.
# - Economy and life: powered by solar energy, water ice harvested from shadowed craters, and Helium-3 processing; a melting pot of engineers, researchers, and settlers who live in a mix of surface domes and underground quarters.
# - Notable features: the Crescent Palace (the ruler’s seat), the Glass Spire (the lunar archives), and the Moonrail transit network that stitches the city to outposts around the pole.
#
# If you’d like, I can tailor Selene Prime further—its history, notable districts, or a day-in-the-life snapshot.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'Premium Photo _ The Lunar City A SciFi Metropoli.png', 'type': 'image/png', 'size': 122356, 'content': <memory at 0x0000018BCBE9AA40>, 'last_modified': datetime.datetime(2025, 12, 30, 6, 32, 55, 975000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Welcome to Lumencrater, the capital city you’re gazing at. It sits in a giant crater on the moon of a distant world, and it’s as much a philosophy as a place—a beacon of light in the void.
#
# What it is called and why
# - Official name: Lumencrater, Capital of the Helix Dominion.
# - Common name: The Prism in the Crater, or simply “Lumen.”
# - Motto: Light without waste, knowledge without mercy.
#
# Geography and layout
# - Core feature: A vast glassy center called the Prism Atrium, where a crystalline lattice collects starlight and translates it into energy and information.
# - The core spire: The Astra Spire, a colossal, translucent tower that seems to grow from the crater floor. It anchors the city’s gravity field and channels the Dominion’s "lumen" energy outward.
# - Terraced rings: Surrounding the core are concentric rings of platforms and terraces—residential districts, markets, academies, and government chambers—each ring stepping outward like a crown of glass.
# - The ring rails: A network of luminous transit rings crisscrosses the crater floor, ferrying people and goods with magnetic-levitation sleds and nano-glide platforms.
# - Outer silhouette: Blue-flecked towers rise like icicles from the crater rim, and distant hover-ships patter the sky above, leaving soft contrails of blue ion glow.
#
# Architecture and aesthetics
# - Materials: Transparent alloys and luminescent glass that shimmer in varying blues and aquamarines. Every surface is etched with micro-crystal filaments that store data and harvest energy.
# - Aesthetic: Organic geometry meets crystalline geometry. Buildings resemble icicles, chandeliers, and weaved lattices—designed to minimize shadow and maximize sky-light capture.
# - The central plaza: The Prism Atrium acts as both civic nerve center and cultural stage. At night it becomes a living aurora, with holographic mosaics painted by light itself.
#
# Governance and society
# - Government: A Council of Lumenwrights—scientists, engineers, and historians who interpret the “lumen” streams to decide policy. They are advised by the Archivists, who guard the cosmos’ data vaults.
# - Society: A meritocratic-collectivist culture that prizes knowledge, repair, and transparency. Citizens specialize in fields like crystallography, astro-archeology, lattice engineering, and xenolinguistics.
# - Religion and philosophy: Not dogmatic, but there is a shared reverence for the cosmos as a library. Festivals celebrate discoveries, migrations, and celestial alignments.
#
# Technology and infrastructure
# - Core technology: A lattice-based energy system that harvests starlight and ambient radiation, converting it into clean power and quantum information streams.
# - Transportation: Hover sleds on the rings, sky-borne couriers, and the “Astra Rails” that fold space slightly to deliver instantaneous transit across the crater.
# - Defense and safety: A multilayered shield that resembles a shimmering ice halo; micro-missile nets and gravity tethers are deployed if asteroid fragments threaten the crater.
#
# Economy and daily life
# - Economy: A knowledge-driven economy—research, data storage, and advanced materials produced from lunar regolith and crystalline cores. They trade with orbital habitats for rare isotopes and cross-stellar records.
# - Daily life: People rise with a pale-blue dawn light from the prism, work in sun-lit workshops, and attend public lectures in the upper rings. Markets are a blend of artisan glasswork, data-sculptures, and star-menu cuisine.
# - Culture: A culture of performances where light, sound, and crystalline prisms create immersive stories. Public rehearsals of “light operas” are as common as debates in the council chambers.
#
# History and lore
# - Founding story: The city rose when a celestial alignment revealed a natural crystal lattice beneath the crater floor. The inhabitants built the Astra Spire to anchor both their city and their future to the cosmos.
# - Key events: The Great Alignment Festival, when the Prism Atrium becomes a living map of neighboring star systems; the Echo Archive Fires, a careful restoration of ancient data that saved centuries of knowledge after a solar storm.
# - Current arc: A new wave of exploration beyond the moon, with teams venturing to nearby orbital rings and distant asteroids to harvest new lumens and document alien languages.
#
# Notable places to visit
# - The Prism Atrium: The heart, where light and data coalesce into a breathtaking display.
# - The Archive Vaults: A labyrinth of crystal shelves holding centuries of cosmos data, guarded by sentient search-bots.
# - The Gardens of Luminance: A terraced oasis where bioluminescent flora thrives in hydrophobic glass.
# - The Spire Plaza: An open-air amphitheater at the base of the Astra Spire, perfect for night lectures and light operas.
# - The Sky Docks: The point of departure for shuttle fleets and sky-courier routes to other habitats.
#
# A short scene
# A citizen descends the ring-steps as the blue glow of the prism washes the crater floor. In the Prism Atrium, a scholar speaks of a newly decoded star-syllable found in an ancient data shard. Light pours from the Astra Spire, weaving through the lattice like liquid sapphire. People listen, spellbound, as the chorus of the city—crystal, glass, and code—tells them that their future is written not in stone, but in light that never fades.
#
# If you’d like, I can tailor Lumencrater further—change its name, adjust the political structure, or weave in a character or two who live there.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
